# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pulling in data
enrolled_df = pd.read_csv("C:\\Users\\ekims\\Documents\\NSS\\DA14\\capstone\\capstone\\data\\enrolled_pop.csv")

# %%
enrolled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3144 entries, 0 to 3143
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Geography                          3144 non-null   object
#  1   Geographic Area Name               3144 non-null   object
#  2   County                             3144 non-null   object
#  3   State                              3144 non-null   object
#  4   E_Total_pop                        3144 non-null   int64
#  5   child_pop                          3144 non-null   int64
#  6   senior_pop                         3144 non-null   int64
#  7   adult_pop                          3144 non-null   int64
#  8   Total Medicaid Coverage Rate       3047 non-null   float64
#  9   Child Medicaid/CHIP Coverage Rate  2967 non-null   float64
#  10  Adult Medicaid Coverage Rate       3034 non-null   float64
# ...

# %%
senior_gap = enrolled_df[['County', 'State', 'senior_pop', 'Senior Pop Enrolled', 'Senior Medicaid Coverage Rate',
                          'State_Enrollment_Senior', 'State_Pop_Senior', 'Senior Gap']].sort_values(by='Senior Gap', ascending=False)
senior_gap.head(5)
# Out:
#                 County        State  senior_pop  Senior Pop Enrolled  \
# 104    Maricopa County      Arizona      718079          7762.153536
# 612        Cook County     Illinois      806307        255608.673500
# 2625     Harris County        Texas      543463          8584.476516
# 223   San Diego County   California      493837         88832.080920
# 216      Orange County   California      498997        115045.330700
#
#       Senior Medicaid Coverage Rate  State_Enrollment_Senior  \
# 104                           0.012             3.016827e+05
# 612                           0.186             3.865184e+05
# 2625                          0.011             8.636092e+05
# 223                           0.164             2.817544e+06
# 216                           0.180             2.817544e+06
#
#       State_Pop_Senior   Senior Gap
# 104            1349934  710316.8465
# 612            2101833  550698.3265
# 2625           3905545  534878.5235
# ...

# %%
adult_gap = senior_gap = enrolled_df[['County', 'State', 'adult_pop', 'Adult Pop Enrolled', 'Adult Medicaid Coverage Rate',
                          'State_Enrollment_Adult', 'State_Pop_Adult', 'Adult Gap']].sort_values(by='Adult Gap', ascending=False)
adult_gap.head(5)
# Out:
#                 County        State  adult_pop  Adult Pop Enrolled  \
# 2625     Harris County        Texas    2847531         7023.662604
# 1860   New York County     New York    1074639        68811.482120
# 104    Maricopa County      Arizona    2631225        76327.843100
# 2581     Dallas County        Texas    1574998        16570.685020
# 223   San Diego County   California    2005627        74748.946140
#
#       Adult Medicaid Coverage Rate  State_Enrollment_Adult  State_Pop_Adult  \
# 2625                         0.009            4.628656e+05         17421175
# 1860                         0.183            1.526090e+06         11792026
# 104                          0.118            3.355613e+05          4129440
# 2581                         0.043            4.628656e+05         17421175
# 223                          0.138            2.795148e+06         23493540
#
#          Adult Gap
# 2625  103155.05580
# 1860   57485.97788
# 104    41147.34490
# 2581   40810.67898
# ...

# %%
child_gap = enrolled_df[['County', 'State', 'child_pop', 'Child Pop Enrolled', 'Child Medicaid/CHIP Coverage Rate',
                          'State_Enrollment_Child', 'State_Pop_Child', 'Child Gap']].sort_values(by='Child Gap', ascending=False)
child_gap.head(5)
# Out:
#                   County        State  child_pop  Child Pop Enrolled  \
# 104      Maricopa County      Arizona    1142683        1.875854e+05
# 2625       Harris County        Texas    1367585        4.463928e+05
# 205   Los Angeles County   California    2301933        1.412931e+06
# 223     San Diego County   California     783318        1.310815e+05
# 2581       Dallas County        Texas     729826        1.576142e+05
#
#       Child Medicaid/CHIP Coverage Rate  State_Enrollment_Child  \
# 104                               0.290            6.336042e+05
# 2625                              0.572            1.883857e+06
# 205                               0.356            4.428970e+06
# 223                               0.242            4.428970e+06
# 2581                              0.409            1.883857e+06
#
#       State_Pop_Child    Child Gap
# 104           1788801  955097.6229
# 2625          8313623  921192.2212
# 205           9754759  889001.8880
# ...
