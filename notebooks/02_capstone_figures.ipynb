# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pulling in data
enrolled_df = pd.read_csv("C:\\Users\\ekims\\Documents\\NSS\\DA14\\capstone\\capstone\\data\\enrolled_pop.csv")

# %%
enrolled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3222 entries, 0 to 3221
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Geography                          3222 non-null   object
#  1   Geographic Area Name               3222 non-null   object
#  2   County                             3222 non-null   object
#  3   State                              3222 non-null   object
#  4   E_Total_pop                        3222 non-null   int64
#  5   child_pop                          3222 non-null   int64
#  6   senior_pop                         3222 non-null   int64
#  7   adult_pop                          3222 non-null   int64
#  8   Total Medicaid Coverage Rate       3047 non-null   float64
#  9   Child Medicaid/CHIP Coverage Rate  2967 non-null   float64
#  10  Adult Medicaid Coverage Rate       3034 non-null   float64
#  11  Senior Medicaid Coverage Rate      2959 non-null   float64
#  12  Total Pop Enrolled                 3047 non-null   float64
#  13  Child Pop Enrolled                 2967 non-null   float64
#  14  Senior Pop Enrolled                2959 non-null   float64
#  15  Adult Pop Enrolled                 3034 non-null   float64
#  16  State_Enrollment_All               3222 non-null   float64
#  17  State_Enrollment_Child             3222 non-null   float64
#  18  State_Enrollment_Senior            3222 non-null   float64
#  19  State_Enrollment_Adult             3222 non-null   float64
#  20  adult_elig                         3144 non-null   float64
#  21  State_Eligibility_Adult            3144 non-null   float64
#  22  State_Pop_All                      3222 non-null   float64
#  23  State_Pop_Child                    3222 non-null   float64
#  24  State_Pop_Senior                   3222 non-null   float64
#  25  State_Pop_Adult                    3222 non-null   float64
#  26  Senior Gap                         2959 non-null   float64
#  27  Child Gap                          2967 non-null   float64
#  28  Adult Gap                          3034 non-null   float64
# dtypes: float64(21), int64(4), object(4)
# memory usage: 730.1+ KB

# %%
#creating sorted senior gap
senior_gap = enrolled_df[['Geographic Area Name','County', 'State', 'senior_pop', 'Senior Pop Enrolled', 'Senior Medicaid Coverage Rate',
                          'State_Enrollment_Senior', 'State_Pop_Senior', 'Senior Gap']].sort_values(by='Senior Gap', ascending=False).reset_index()
top_5_senior = senior_gap.head(5)

# %%
plt.bar(top_5_senior['Geographic Area Name'], top_5_senior['Senior Gap'])

plt.xlabel('County, State')
plt.ylabel('Eligible Seniors Not Enrolled')
plt.title('Top 5 Counties, Senior Enrollment Gap')
plt.xticks(rotation = 70)
plt.savefig('top_5_senior', bbox_inches='tight')

# %%
adult_gap = senior_gap = enrolled_df[['Geographic Area Name', 'County', 'State', 'adult_pop', 'Adult Pop Enrolled', 'Adult Medicaid Coverage Rate',
                          'State_Enrollment_Adult', 'State_Pop_Adult', 'Adult Gap']].sort_values(by='Adult Gap', ascending=False).reset_index()
top_5_adult = adult_gap.head(5)

# %%
plt.bar(top_5_adult['Geographic Area Name'], top_5_adult['Adult Gap'])

plt.xlabel('County, State')
plt.ylabel('Eligible Adults Not Enrolled')
plt.title('Top 5 Counties, Adult Enrollment Gap (based on income)')
plt.xticks(rotation = 70)
plt.savefig('top_5_adult', bbox_inches='tight')

# %%
child_gap = enrolled_df[['Geographic Area Name', 'County', 'State', 'child_pop', 'Child Pop Enrolled', 'Child Medicaid/CHIP Coverage Rate',
                          'State_Enrollment_Child', 'State_Pop_Child', 'Child Gap']].sort_values(by='Child Gap', ascending=False).reset_index()
top_5_child = child_gap.head(5)
top_5_child
# Out:
#    index            Geographic Area Name              County        State  \
# 0    104        Maricopa County, Arizona     Maricopa County      Arizona
# 1   2625            Harris County, Texas       Harris County        Texas
# 2    205  Los Angeles County, California  Los Angeles County   California
# 3    223    San Diego County, California    San Diego County   California
# 4   2581            Dallas County, Texas       Dallas County        Texas
#
#    child_pop  Child Pop Enrolled  Child Medicaid/CHIP Coverage Rate  \
# 0    1142683           187585.38                              0.290
# 1    1367585           446392.78                              0.572
# 2    2301933          1412931.11                              0.356
# 3     783318           131081.49                              0.242
# 4     729826           157614.19                              0.409
#
#    State_Enrollment_Child  State_Pop_Child  Child Gap
# 0               633604.25        1788801.0  955097.62
# 1              1883856.53        8313623.0  921192.22
# 2              4428969.95        9754759.0  889001.89
# 3              4428969.95        9754759.0  652236.51
# 4              1883856.53        8313623.0  572211.81

# %%
plt.bar(top_5_child['Geographic Area Name'], top_5_child['Child Gap'])

plt.xlabel('County, State')
plt.ylabel('Eligible Children Not Enrolled')
plt.title('Top 5 Counties, Child Enrollment Gap')
plt.xticks(rotation = 70)
plt.savefig('top_5_child', bbox_inches='tight')
